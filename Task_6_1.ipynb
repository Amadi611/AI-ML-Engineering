# %% [markdown]
# The main goal is to train an ANN (Artificial Neural Network) to predict whether a mobile phone belongs to:
#
# 1 → High price
# 0 → Low price
# upload the CSV file and check the column

# %%
from google.colab import files
import io

print('Please upload the CSV file:')
uploaded = files.upload()

# Assuming only one file is uploaded, get its name
if uploaded:
    uploaded_filename = next(iter(uploaded))
    print(f'File "{uploaded_filename}" uploaded successfully.')
else:
    uploaded_filename = None
    print('No file was uploaded.')
# Out:
# Please upload the CSV file:
#      <input type="file" id="files-9e13d0f2-b90f-417d-9697-d58b88e7194e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e13d0f2-b90f-417d-9697-d58b88e7194e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# After uploading the file, the next cell will be updated to use the uploaded file's name. Please run the previous cell first, upload your file, and then run the next cell.

# %%
import pandas as pd

# Ensure 'uploaded_filename' is defined from the previous upload cell
if 'uploaded_filename' in locals() and uploaded_filename:
    df = pd.read_csv(uploaded_filename)
    display(df.head())
else:
    print("Please run the file upload cell first and upload your CSV file.")
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# Step 2 — Separate Features (X) and Target (Y)
# dataset should have a column representing the price range, usually:
#
# *price_range*
#
# X = mobile phone features such as RAM, battery power, internal memory, etc.
# Y = price_range (0 or 1)

# %%
X = df.drop("price_range", axis=1)
Y = df["price_range"]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2000, 20)
# (2000,)

# %% [markdown]
# Step 3 — Split Training and Testing Data
# 75% training and 25% testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y,
    test_size=0.25,
    random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (1500, 20)
# Testing data: (500, 20)

# %% [markdown]
# Step 4 — Create ANN Model
# 1st hidden layer → 8 neurons
# 2nd hidden layer → 4 neurons

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(8, activation='relu', input_shape=(X_train.shape[1],)))

model.add(Dense(4, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# ...

# %% [markdown]
# Step 5 — Compile the Model
# binary classification problem, use binary_crossentropy.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Step 6 — Train for 100 Epochs
# 100 epochs and batch size 32

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5387 - loss: 110.0976 - val_accuracy: 0.5600 - val_loss: 39.9984
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5420 - loss: 17.0415 - val_accuracy: 0.5560 - val_loss: 7.4559
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5513 - loss: 3.5081 - val_accuracy: 0.5760 - val_loss: 1.8074
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5773 - loss: 1.2125 - val_accuracy: 0.5580 - val_loss: 0.9795
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5607 - loss: 0.8256 - val_accuracy: 0.5500 - val_loss: 0.7968
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5720 - loss: 0.7464 - val_accuracy: 0.5700 - val_loss: 0.7644
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5673 - loss: 0.6970 - val_accuracy: 0.5600 - val_loss: 0.7444
# Epoch 8/100
# ...

# %% [markdown]
# Step 7 — Check Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Test Accuracy:", accuracy)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6340 - loss: 0.6270
# Test Accuracy: 0.6340000033378601

# %% [markdown]
# Step 8 — Save the Weights

# %%
model.save_weights("mobile_price_model.weights.h5")
